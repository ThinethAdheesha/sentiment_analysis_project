# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import string

# %%
import pandas as pd

data = pd.read_csv('../artifacts/sentiment_analysis.csv')

# %%
data.head()
# Out:
#    id  label                                              tweet
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...

# %%
data.shape
# Out:
# (7920, 3)

# %% [markdown]
# ## DATE PREPOCESSING

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7915    False
# 7916    False
# 7917    False
# 7918    False
# 7919    False
# Length: 7920, dtype: bool

# %% [markdown]
# ## text preprocessing

# %%
data["tweet"] = data["tweet"].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
data["tweet"].head(5)
# Out:
# 0    #fingerprint #pregnancy test https://goo.gl/h1...
# 1    finally a transparant silicon case ^^ thanks t...
# 2    we love this! would you go? #talk #makememorie...
# 3    i'm wired i know i'm george i was made that wa...
# 4    what amazing service! apple won't even talk to...
# Name: tweet, dtype: object

# %% [markdown]
# ## remove links

# %%
data["tweet"] = data['tweet'].apply(lambda x: " ".join(re.sub(r'^https?:\/\/.*[\r\n]*', '', x, flags=re.MULTILINE) for x in x.split()))

# %%
data["tweet"].head(5)
# Out:
# 0    #fingerprint #pregnancy test  #android #apps #...
# 1    finally a transparant silicon case ^^ thanks t...
# 2    we love this! would you go? #talk #makememorie...
# 3    i'm wired i know i'm george i was made that wa...
# 4    what amazing service! apple won't even talk to...
# Name: tweet, dtype: object

# %% [markdown]
# ## remove punctuations

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

data["tweet"] = data["tweet"].apply(remove_punctuations)

# %%
data["tweet"].tail(10)
# Out:
# 7910    perfect match instagood applewatch red instagr...
# 7911    i am completely in love with the new iphone em...
# 7912    tune in turn on drop out  gtd in one app  mobi...
# 7913    ok so my galaxy crashed after one day now i ha...
# 7914    gain followers rt this must follow me i follow...
# 7915    live out loud lol liveoutloud selfie smile son...
# 7916    we would like to wish you an amazing day make ...
# 7917    helping my lovely 90 year old neighbor with he...
# 7918    finally got my smart pocket wifi stay connecte...
# 7919    apple barcelona apple store bcn barcelona trav...
# Name: tweet, dtype: object

# %%
data["tweet"] = data['tweet'].str.replace(r'\d+', '', regex=True)

# %%
data["tweet"].tail(10)
# Out:
# 7910    perfect match instagood applewatch red instagr...
# 7911    i am completely in love with the new iphone em...
# 7912    tune in turn on drop out  gtd in one app  mobi...
# 7913    ok so my galaxy crashed after one day now i ha...
# 7914    gain followers rt this must follow me i follow...
# 7915    live out loud lol liveoutloud selfie smile son...
# 7916    we would like to wish you an amazing day make ...
# 7917    helping my lovely  year old neighbor with her ...
# 7918    finally got my smart pocket wifi stay connecte...
# 7919    apple barcelona apple store bcn barcelona trav...
# Name: tweet, dtype: object

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting joblib (from nltk)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.11.6-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 176.1 kB/s eta 0:00:06
#    ------------- -------------------------- 0.5/1.5 MB 176.1 kB/s eta 0:00:06
#    ------------- -------------------------- 0.5/1.5 MB 176.1 kB/s eta 0:00:06
#    ------------- -------------------------- 0.5/1.5 MB 176.1 kB/s eta 0:00:06
#    ------------- -------------------------- 0.5/1.5 MB 176.1 kB/s eta 0:00:06
#    ------------- -------------------------- 0.5/1.5 MB 176.1 kB/s eta 0:00:06
#    ------------- -------------------------- 0.5/1.5 MB 176.1 kB/s eta 0:00:06
#    -------------------- ------------------- 0.8/1.5 MB 188.3 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 188.3 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 188.3 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 188.3 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 188.3 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 188.3 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 188.3 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 188.3 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 188.3 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 188.3 kB/s eta 0:00:04
#    --------------------------- ------------ 1.0/1.5 MB 157.6 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 157.6 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 157.6 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 157.6 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 157.6 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 157.6 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 157.6 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 157.6 kB/s eta 0:00:03
#    ---------------------------------- ----- 1.3/1.5 MB 160.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 160.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 160.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 160.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 160.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 160.2 kB/s eta 0:00:02
#    ---------------------------------------- 1.5/1.5 MB 157.5 kB/s eta 0:00:00
# Downloading regex-2024.11.6-cp313-cp313-win_amd64.whl (273 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Installing collected packages: regex, joblib, click, nltk
#
#    ---------------------------------------- 0/4 [regex]
#    ---------- ----------------------------- 1/4 [joblib]
#    ---------- ----------------------------- 1/4 [joblib]
#    ---------- ----------------------------- 1/4 [joblib]
#    -------------------- ------------------- 2/4 [click]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ---------------------------------------- 4/4 [nltk]
#
# Successfully installed click-8.2.1 joblib-1.5.1 nltk-3.9.1 regex-2024.11.6

# %%
import nltk

# %%
nltk.download('stopwords', download_dir='../static/model')
# Out:
# [nltk_data] Downloading package stopwords to ../static/model...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
with open('../static/model/corpora/stopwords/english', 'r') as file:
    sw = file.read().splitlines()

# %%
sw
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
data["tweet"] = data["tweet"].apply(lambda x: " ".join(x for x in x.split() if x not in sw))

# %%
data["tweet"].tail(10)
# Out:
# 7910    perfect match instagood applewatch red instagr...
# 7911    completely love new iphone emojis iphone apple...
# 7912    tune turn drop gtd one app mobile mind meditat...
# 7913    ok galaxy crashed one day wait til monday skyr...
# 7914    gain followers rt must follow follow back foll...
# 7915    live loud lol liveoutloud selfie smile sony mu...
# 7916    would like wish amazing day make every minute ...
# 7917    helping lovely year old neighbor ipad morning ...
# 7918    finally got smart pocket wifi stay connected a...
# 7919    apple barcelona apple store bcn barcelona trav...
# Name: tweet, dtype: object

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
import pandas as pd

# Example: Load CSV file into 'data'
data = pd.read_csv("../artifacts/sentiment_analysis.csv")

# %%
data["tweet"] = data["tweet"].apply(lambda x: " ".join(ps.stem(x) for x in x.split()))

# %%
data["tweet"].tail(10)
# Out:
# 7910    perfect match #instagood #applewatch #red #ins...
# 7911    i am complet in love with the new iphon emojis...
# 7912    tune in. turn on. drop out. & #gtd in one app!...
# 7913    ok so my galaxi crash after one day now i have...
# 7914    gain follow rt thi must follow me i follow bac...
# 7915    live out loud #lol #liveoutloud #selfi #smile ...
# 7916    we would like to wish you an amaz day! make ev...
# 7917    help my love 90 year old neighbor with her ipa...
# 7918    final got my #smart #pocket #wifi stay connect...
# 7919    appl barcelona!!! #appl #store #bcn #barcelona...
# Name: tweet, dtype: object

# %%
from collections import Counter
vocab = Counter()

# %%
vocab
# Out:
# Counter()

# %%
for sentence in data['tweet']:
    vocab.update(sentence.split())

# %%
len(vocab)
# Out:
# 28459

# %%
# Out:
# 28459

# %%
tokens = [key for key in vocab if vocab[key] > 10]

# %%
len(tokens)
# Out:
# 1346

# %%
data.shape
# Out:
# (7920, 3)

# %%
tokens
# Out:
# ['#android',
#  '#app',
#  '#beauti',
#  '#cute',
#  '#health',
#  '#iger',
#  '#iphoneonli',
#  '#iphonesia',
#  '#iphon',
#  'final',
#  'a',
#  'case',
#  'thank',
#  'to',
#  'my',
#  ':)',
#  '#yay',
#  '#soni',
#  '#xperia',
#  '#s',
#  'we',
#  'love',
#  'this!',
#  'would',
#  'you',
#  '#relax',
#  '#smartphon',
#  '#wifi',
#  "i'm",
#  'i',
#  'know',
#  'wa',
#  'made',
#  'that',
#  'way',
#  ';)',
#  '#home',
#  'what',
#  'amaz',
#  'appl',
#  "won't",
#  'even',
#  'talk',
#  'me',
#  'about',
#  'have',
#  'pay',
#  'them',
#  'for',
#  'their',
#  'stupid',
#  'iphon',
#  'softwar',
#  'updat',
#  'fuck',
#  'up',
#  'phone',
#  'big',
#  'time',
#  'happi',
#  'us',
#  '..',
#  '#instap',
#  '#instadaili',
#  '#u',
#  'new',
#  'type',
#  'charger',
#  'cabl',
#  '#uk',
#  '…',
#  '#amazon',
#  'year',
#  '2018',
#  '#newyear',
#  '#technolog',
#  '#iphonex',
#  'go',
#  'shop',
#  'again',
#  'listen',
#  'music',
#  '#music',
#  '#likeforlik',
#  'photo:',
#  '#fun',
#  '#selfi',
#  '#water',
#  '#camera',
#  '#picoftheday',
#  '#sun',
#  '#instagood',
#  '#boy',
#  'hey',
#  '#appl',
#  'when',
#  'make',
#  'ipod',
#  'dont',
#  'it',
#  'or',
#  'not',
#  'crash',
#  'everi',
#  'but',
#  'doe',
#  'need',
#  '@appl',
#  'realli',
#  'drop',
#  'the',
#  'with',
#  'give',
#  'in',
#  'becaus',
#  'ha',
#  'no',
#  'android',
#  'just',
#  'anoth',
#  'purchas',
#  'lol',
#  'is',
#  'play',
#  '#ipad',
#  '#shop',
#  'batteri',
#  'so',
#  'charg',
#  'and',
#  'by',
#  'from',
#  '#saturday',
#  '#summer',
#  'like',
#  'share',
#  'if',
#  'want',
#  'thi',
#  '...',
#  '!!',
#  '#iphonesia,',
#  '#iphone,',
#  '#instagood,',
#  '#instagram,',
#  '#photooftheday,',
#  '#tweegram,',
#  'reason',
#  "don't",
#  'one.',
#  '#suck',
#  '#truth',
#  'how',
#  'store',
#  'be',
#  'out',
#  'of',
#  'screen',
#  "it'",
#  'monday',
#  'ur',
#  '!!!',
#  '#art',
#  '#friend',
#  'on',
#  'design',
#  'face',
#  'email',
#  'as',
#  ':',
#  'me,',
#  'there',
#  'seem',
#  '#pie',
#  "i'v",
#  'had',
#  'button',
#  'back',
#  'onc',
#  'your',
#  'goe',
#  'complet',
#  'black',
#  'keep',
#  'get',
#  'text',
#  'all',
#  'day',
#  "can't",
#  'check',
#  'wallpap',
#  '#phone',
#  '#galaxi',
#  '#samsung',
#  '3',
#  'patent',
#  'where',
#  'art',
#  '=',
#  'million',
#  'are',
#  'parti',
#  'now',
#  '$&@*#',
#  'mess',
#  "haven't",
#  'done',
#  'noth',
#  '#$&@*#',
#  '!',
#  'touch',
#  'start',
#  'up.',
#  'lose',
#  '&',
#  'pic',
#  'will',
#  'kill',
#  '#hateappl',
#  'do',
#  'case!',
#  '#flower',
#  '#green',
#  '#new',
#  '#iphone4',
#  'must',
#  'watch',
#  '#youtub',
#  '#subscrib',
#  '#daili',
#  '#vlog',
#  '#twitch',
#  '#game',
#  '#ps4',
#  '#xbox',
#  '#io',
#  'you!',
#  '#live',
#  '#laugh',
#  '#life',
#  '#food',
#  '#instago',
#  '#instahub',
#  '#instagram…',
#  '#dog',
#  '#famili',
#  '#bestfriend',
#  '2016',
#  'taken',
#  '#sunset',
#  '#ski',
#  'bought',
#  'earli',
#  '#s4',
#  'receiv',
#  'note',
#  'mani',
#  'an',
#  'app',
#  'whi',
#  'delet',
#  'song',
#  '#itun',
#  'freak',
#  'ios7',
#  'here',
#  'window',
#  'more',
#  'than',
#  'custom',
#  '5s',
#  's',
#  'stand',
#  'bad',
#  'same',
#  'camera',
#  '#smile',
#  'they',
#  'you,',
#  'let',
#  'you.',
#  '#photo',
#  '#sunday',
#  '#alway',
#  '#photooftheday',
#  '#ey',
#  '#me',
#  '#ootd',
#  '#fashion',
#  '#blackandwhit',
#  'set',
#  '.',
#  '#video',
#  '#produc',
#  '#follow',
#  '#movi',
#  'phone!',
#  '#pink',
#  '#sweet',
#  '#tweegram',
#  'week',
#  '#iphone8',
#  'moment',
#  'see',
#  'differ',
#  '#photographi',
#  '#natur',
#  '#landscap',
#  '#tree',
#  '#travel',
#  '#a7',
#  'googl',
#  'cut',
#  'itun',
#  'look',
#  'got',
#  'christma',
#  '<3',
#  '#christma',
#  '#girl',
#  '#instacool',
#  '#play',
#  '#ipod',
#  '#free',
#  'now!',
#  '#appstor',
#  'at',
#  '#joy',
#  '#peac',
#  '#cloud',
#  '#iphone…',
#  'babi',
#  'boy',
#  '#babi',
#  '#pet',
#  'him',
#  '#fail',
#  '#tech',
#  '#funni',
#  'hate',
#  'ipad',
#  'one',
#  'tablet',
#  'person',
#  'use',
#  'im',
#  'fan',
#  'think',
#  'product',
#  'friday',
#  'call',
#  '#blackfriday',
#  '#holiday',
#  '#gift',
#  '#newyork',
#  '#busi',
#  '#money',
#  '#birthday',
#  '#tv',
#  '#comput',
#  '#school',
#  'serious',
#  'into',
#  'someon',
#  'other',
#  'broke',
#  'month',
#  'after',
#  'phone.',
#  'good',
#  'job',
#  'apple,',
#  'actual',
#  'am',
#  'replac',
#  "that'",
#  'still',
#  'rt',
#  '#cool',
#  '#pictur',
#  'life',
#  '#beach',
#  '#sport',
#  'bit',
#  'yet',
#  'arriv',
#  'gain',
#  'follow',
#  'everyon',
#  'who',
#  '#sougofollow',
#  '#ff',
#  '#iphoneographi',
#  '#iphonephotographi',
#  '#mobil',
#  '#color',
#  'user',
#  '#sexi',
#  '#date',
#  'can',
#  '#random',
#  '#instamood',
#  '#amaz',
#  '#creativ',
#  '#f4f',
#  '#hot',
#  '#l4l',
#  '#origin',
#  '#pop',
#  '#red',
#  '#rock',
#  '#soul',
#  '#singer',
#  '#song',
#  'which',
#  'thought',
#  "i'd",
#  'feel',
#  'broken',
#  '....',
#  '#happi',
#  'light',
#  '#light',
#  '#indonesia',
#  '#a6000',
#  '#5',
#  '#gold',
#  '#potd',
#  'reset',
#  'work',
#  '#white',
#  '#chill',
#  'cover',
#  "apple'",
#  'came',
#  '2',
#  'come',
#  '<<<<<',
#  '#followsunday',
#  '#followback',
#  '#rt',
#  '#teamfollowback',
#  '#retweet',
#  '#iphone...',
#  'ya',
#  'thing',
#  'i’m',
#  '4',
#  'it’',
#  'been',
#  'alreadi',
#  'problem',
#  'again.',
#  'issu',
#  'abl',
#  'retweet',
#  '#shoot',
#  '#pic',
#  'put',
#  'price',
#  'devic',
#  'box',
#  'gold',
#  'memori',
#  'her',
#  'dead',
#  'brother',
#  '–',
#  'game',
#  'oh',
#  'ani',
#  '#win',
#  'enjoy',
#  '#ps3',
#  '#playstat',
#  '#gamer',
#  '#instagram',
#  '#2012',
#  'someth',
#  'right',
#  'today.',
#  '#earphon',
#  '#lifestyl',
#  '#fuckyou',
#  'never',
#  'end',
#  'littl',
#  'cute',
#  'birthday',
#  'present',
#  '#macbookpro',
#  '#macbook',
#  'quot',
#  '#quot',
#  '#word',
#  '#tweetgram',
#  'great',
#  'servic',
#  'repair',
#  'few',
#  'hour',
#  'lost',
#  'everyth',
#  'compani',
#  'samsung',
#  'featur',
#  "didn't",
#  '#',
#  '#coffe',
#  'creat',
#  '#iphone.',
#  '#spring',
#  'special',
#  'valentin',
#  '>>',
#  'https://itunes.apple.com/us/app/love360/id809353957?mt=8',
#  '#nowplay',
#  '#daughter',
#  'poem',
#  '#valentin',
#  'photo',
#  '#car',
#  '@',
#  '#banana',
#  'spend',
#  'our',
#  'less',
#  'much',
#  '#book',
#  'say',
#  'u',
#  'took',
#  'download',
#  '#ios7',
#  '(taken',
#  'instagram',
#  'ad',
#  'myself',
#  'twitter',
#  '#educ',
#  '#mom',
#  '6',
#  'n',
#  'miss',
#  'last',
#  'min',
#  'rid',
#  'absolut',
#  '#tmobil',
#  '#lol',
#  'annoy',
#  'buy',
#  'full',
#  '#blog',
#  '#style',
#  '#bestoftheday',
#  '#pretti',
#  'send',
#  'turn',
#  'imessag',
#  'she',
#  'sleep',
#  '#popular',
#  '#shotoniphon',
#  '#iphone7plu',
#  '#photograph',
#  '#case',
#  '#day',
#  'these',
#  'sync',
#  'onli',
#  '8',
#  'second',
#  'sweet',
#  ':3',
#  '#good',
#  '#nice',
#  'wait',
#  'hand',
#  'nice',
#  'first',
#  '1',
#  'car',
#  'siri',
#  'doesnt',
#  '#siri',
#  'liter',
#  'contact',
#  '-',
#  'wonder',
#  'avail',
#  '#laptop',
#  '#vaio',
#  '#black',
#  'dear',
#  'blackberri',
#  'best',
#  'soon',
#  '#yum',
#  'it.',
#  'mac',
#  '7',
#  'veri',
#  '#updat',
#  'display',
#  'told',
#  'stop',
#  'three',
#  'gear',
#  'well',
#  'pictur',
#  'past',
#  ':(',
#  'free',
#  '#singl',
#  'too!',
#  '@capetownsup',
#  '#sup',
#  '#surf',
#  '#capetown',
#  'pro',
#  "doesn't",
#  'half',
#  'stuff',
#  '#excit',
#  '#today',
#  'both',
#  'mine',
#  'piss',
#  'off',
#  'offici',
#  'keyboard',
#  'though',
#  'enough',
#  'money',
#  'then',
#  '#like',
#  '#instagood…',
#  '#jj',
#  '#parti',
#  '#makeup',
#  '#valentinesday',
#  '#portrait',
#  '#myself',
#  'shot',
#  '#sonyalpha',
#  '#market',
#  'wifi',
#  'password',
#  '#addict',
#  '#prophet',
#  '#husband',
#  'http://ift.tt/2bor0kb',
#  'http://ift.tt/2asurcj',
#  '#kindl',
#  'februari',
#  '2017',
#  'upgrad',
#  '#iphone7',
#  'help',
#  "there'",
#  'wrong',
#  'least',
#  'real',
#  '#tablet',
#  'visit',
#  'hi',
#  'world',
#  'old',
#  '#followm',
#  '#like4lik',
#  '#samsung…',
#  '#swag',
#  '#cat',
#  '#edit',
#  'suck',
#  'may',
#  '#batteri',
#  '#design',
#  'book',
#  '#night',
#  '#perfect',
#  '#instaphoto',
#  'welcom',
#  '#draw',
#  'os',
#  '3g',
#  'throw',
#  '#fan',
#  'w',
#  'take',
#  'two',
#  'apple.',
#  'next',
#  'smartphon',
#  '2015',
#  'middl',
#  'night',
#  'over',
#  'some',
#  'access',
#  'find',
#  '#citi',
#  '#the',
#  '#big',
#  ',',
#  '?',
#  'tweet',
#  '#apple,',
#  '#custom',
#  '#goodnight',
#  '#uae',
#  '#ipadmini',
#  '#iphone5',
#  '#great',
#  '#deal',
#  '#passion',
#  'friend',
#  '#mac',
#  'whole',
#  '#god',
#  '#thank',
#  '#final',
#  'famili',
#  '#note2',
#  'version',
#  'hot',
#  'high',
#  'tech',
#  'usb',
#  '#geek',
#  '#bot',
#  '#googl',
#  '#gadget',
#  '#power',
#  '#pc',
#  'too',
#  'pick',
#  'wish',
#  'day!',
#  'minut',
#  'count',
#  '#tl',
#  '#accessori',
#  'home',
#  'drive',
#  'through',
#  'he',
#  'me.',
#  '#imessag',
#  '#text',
#  '#gay',
#  'readi',
#  '#cellphon',
#  'space',
#  '#tattoo',
#  'id',
#  'total',
#  'excit',
#  'ye',
#  'macbook',
#  'air',
#  'instal',
#  'fit',
#  '#fit',
#  'galaxi',
#  'plu',
#  '#florida',
#  '#twitter',
#  '#sale',
#  '#window',
#  '#nokia',
#  '#motorola',
#  '#lg',
#  '#offer',
#  '#best',
#  'pleas',
#  'without',
#  '#unitedst',
#  '#guitarplay',
#  'comput',
#  'smart',
#  '#galaxynot',
#  'calendar',
#  'cant',
#  'icloud',
#  'freez',
#  'ever',
#  'sinc',
#  'team',
#  'tri',
#  'ipod,',
#  "wouldn't",
#  '#sister',
#  'small',
#  'blue',
#  '—',
#  'steemit',
#  '#blue',
#  '#stori',
#  '#sonylen',
#  '#len',
#  '#sonyphotographi',
#  '#imag',
#  '#photofe',
#  '#feed',
#  '#gorgeou',
#  '#ig',
#  '#dress',
#  'lock',
#  ':d',
#  '#awesom',
#  '#colleg',
#  'http://reallyreal.com/',
#  'true',
#  '#chocol',
#  'shit.',
#  '#usa',
#  '#help',
#  '#ador',
#  'life.',
#  '#nofilt',
#  'drink',
#  '#fruit',
#  '#purpl',
#  '#drink',
#  '#garden',
#  '#андроид',
#  'guys!',
#  '#bestpric',
#  'jun',
#  '16,',
#  'unlock',
#  'caus',
#  'manag',
#  '#bless',
#  'could',
#  'close',
#  'morn',
#  '#nike',
#  'today',
#  '#imac',
#  '#in',
#  'sell',
#  'laptop',
#  'date',
#  'run',
#  'live',
#  'roll',
#  '#verizon',
#  "#valentine'",
#  '#year',
#  '#2018',
#  'sunday',
#  'work.',
#  '#s3',
#  '#work',
#  'headphon',
#  'io',
#  '#show',
#  '#sound',
#  '#itali',
#  'learn',
#  '#delici',
#  '#morn',
#  '#friday',
#  '#orang',
#  'long',
#  'fail',
#  'far',
#  'away',
#  '#ebay',
#  'power',
#  'fix',
#  'random',
#  '#iphone6',
#  '#mine',
#  '#silver',
#  'provid',
#  'o',
#  'experi',
#  '#oneplu',
#  '#emoji',
#  'man',
#  'wanna',
#  "you'r",
#  'tell',
#  'cool',
#  '#kid',
#  'down',
#  'account',
#  'while',
#  'phone,',
#  'between',
#  'peopl',
#  '#model',
#  '#i',
#  '#it',
#  '#mi',
#  '#you',
#  'anyon',
#  'els',
#  'number',
#  'nokia',
#  'rhyme',
#  'http://bit.ly/rhymeapp',
#  '#rhyme',
#  'fun',
#  'restor',
#  'show',
#  '#igdaili',
#  'chang',
#  'x',
#  '#upgrad',
#  'open',
#  '#gratitud',
#  '#blackberri',
#  '#look',
#  '#wow',
#  '#sonyphoto',
#  '#top',
#  'video',
#  'it,',
#  '#phonecas',
#  'june',
#  '#sad',
#  'might',
#  '#india',
#  '#canada',
#  '#europ',
#  '#galaxys3',
#  '#headphon',
#  'care',
#  'map',
#  'order',
#  'sent',
#  '#annoy',
#  'went',
#  '#insta',
#  '#newphon',
#  '#galaxys5',
#  '#london',
#  '#vsco',
#  'track',
#  'catch',
#  '#love',
#  'finger',
#  'top',
#  '#woman',
#  'apple!',
#  'summer',
#  '#film',
#  '#watch',
#  'own',
#  '#now',
#  'cat',
#  '#instalik',
#  '#sony…',
#  '#proud',
#  'today!',
#  '#hateiphon',
#  'befor',
#  '#nyc',
#  '#ni',
#  '#vscocam',
#  'most',
#  'pretti',
#  'day.',
#  'bring',
#  'better',
#  '#kiss',
#  'via',
#  '#fresh',
#  '|',
#  'hello',
#  'soni',
#  '#inspir',
#  '#inlov',
#  '#luxuri',
#  '#note',
#  '10pc',
#  'exquisit',
#  'squishi',
#  'charm',
#  'http://ebay.to/2yi9mr7',
#  'strap',
#  '#toy',
#  'decor',
#  '#cake',
#  'tv',
#  "they'r",
#  '#fml',
#  'facebook',
#  '20',
#  'wipe',
#  '#human',
#  'word',
#  '#fuck',
#  '/',
#  '6s',
#  ...]

# %%
def save_vocabulary(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w', encoding="utf-8")
    file.write(data)
    file.close()

save_vocabulary(tokens, '../static/model/vocabulary.txt')

# %% [markdown]
# ## Divide Dataset

# %%
X = data['tweet']
y = data['label']

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from scikit-learn) (2.3.2)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from scikit-learn) (1.5.1)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.7 MB 631.0 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/8.7 MB 631.0 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/8.7 MB 677.5 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.0/8.7 MB 747.7 kB/s eta 0:00:11
#    ------ --------------------------------- 1.3/8.7 MB 788.7 kB/s eta 0:00:10
#    ------- -------------------------------- 1.6/8.7 MB 816.7 kB/s eta 0:00:09
#    -------- ------------------------------- 1.8/8.7 MB 866.4 kB/s eta 0:00:08
#    --------- ------------------------------ 2.1/8.7 MB 907.3 kB/s eta 0:00:08
#    ---------- ----------------------------- 2.4/8.7 MB 964.4 kB/s eta 0:00:07
#    ------------ --------------------------- 2.6/8.7 MB 1.0 MB/s eta 0:00:07
#    -------------- ------------------------- 3.1/8.7 MB 1.1 MB/s eta 0:00:06
#    --------------- ------------------------ 3.4/8.7 MB 1.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 3.7/8.7 MB 1.1 MB/s eta 0:00:05
#    ------------------ --------------------- 3.9/8.7 MB 1.2 MB/s eta 0:00:05
#    -------------------- ------------------- 4.5/8.7 MB 1.2 MB/s eta 0:00:04
#    --------------------- ------------------ 4.7/8.7 MB 1.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.0/8.7 MB 1.2 MB/s eta 0:00:03
#    ------------------------ --------------- 5.2/8.7 MB 1.2 MB/s eta 0:00:03
#    ------------------------- -------------- 5.5/8.7 MB 1.2 MB/s eta 0:00:03
#    -------------------------- ------------- 5.8/8.7 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 6.0/8.7 MB 1.2 MB/s eta 0:00:03
#    --------------------------- ------------ 6.0/8.7 MB 1.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 6.3/8.7 MB 1.2 MB/s eta 0:00:02
#    ------------------------------ --------- 6.6/8.7 MB 1.2 MB/s eta 0:00:02
#    ------------------------------- -------- 6.8/8.7 MB 1.2 MB/s eta 0:00:02
#    -------------------------------- ------- 7.1/8.7 MB 1.2 MB/s eta 0:00:02
#    --------------------------------- ------ 7.3/8.7 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 7.6/8.7 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 7.9/8.7 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.1/8.7 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 1.2 MB/s eta 0:00:00
# Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.5 MB 961.8 kB/s eta 0:00:40
#     --------------------------------------- 0.8/38.5 MB 1.0 MB/s eta 0:00:37
#    - -------------------------------------- 1.0/38.5 MB 1.1 MB/s eta 0:00:35
#    - -------------------------------------- 1.3/38.5 MB 1.1 MB/s eta 0:00:34
#    - -------------------------------------- 1.6/38.5 MB 1.1 MB/s eta 0:00:34
#    - -------------------------------------- 1.8/38.5 MB 1.1 MB/s eta 0:00:33
#    -- ------------------------------------- 2.1/38.5 MB 1.1 MB/s eta 0:00:33
#    -- ------------------------------------- 2.4/38.5 MB 1.2 MB/s eta 0:00:32
#    -- ------------------------------------- 2.6/38.5 MB 1.2 MB/s eta 0:00:32
#    -- ------------------------------------- 2.9/38.5 MB 1.2 MB/s eta 0:00:31
#    --- ------------------------------------ 3.1/38.5 MB 1.2 MB/s eta 0:00:31
#    --- ------------------------------------ 3.4/38.5 MB 1.2 MB/s eta 0:00:30
#    --- ------------------------------------ 3.7/38.5 MB 1.2 MB/s eta 0:00:30
#    ---- ----------------------------------- 3.9/38.5 MB 1.2 MB/s eta 0:00:30
#    ---- ----------------------------------- 4.2/38.5 MB 1.2 MB/s eta 0:00:29
#    ---- ----------------------------------- 4.2/38.5 MB 1.2 MB/s eta 0:00:29
#    ---- ----------------------------------- 4.5/38.5 MB 1.1 MB/s eta 0:00:30
#    ---- ----------------------------------- 4.7/38.5 MB 1.2 MB/s eta 0:00:29
#    ----- ---------------------------------- 5.0/38.5 MB 1.2 MB/s eta 0:00:30
#    ----- ---------------------------------- 5.0/38.5 MB 1.2 MB/s eta 0:00:30
#    ----- ---------------------------------- 5.2/38.5 MB 1.1 MB/s eta 0:00:30
#    ----- ---------------------------------- 5.5/38.5 MB 1.1 MB/s eta 0:00:30
#    ----- ---------------------------------- 5.8/38.5 MB 1.1 MB/s eta 0:00:30
#    ----- ---------------------------------- 5.8/38.5 MB 1.1 MB/s eta 0:00:30
#    ------ --------------------------------- 6.0/38.5 MB 1.1 MB/s eta 0:00:30
#    ------ --------------------------------- 6.3/38.5 MB 1.1 MB/s eta 0:00:30
#    ------ --------------------------------- 6.3/38.5 MB 1.1 MB/s eta 0:00:30
#    ------ --------------------------------- 6.6/38.5 MB 1.1 MB/s eta 0:00:31
#    ------- -------------------------------- 6.8/38.5 MB 1.1 MB/s eta 0:00:30
#    ------- -------------------------------- 6.8/38.5 MB 1.1 MB/s eta 0:00:30
#    ------- -------------------------------- 7.1/38.5 MB 1.0 MB/s eta 0:00:31
#    ------- -------------------------------- 7.3/38.5 MB 1.0 MB/s eta 0:00:30
#    ------- -------------------------------- 7.6/38.5 MB 1.0 MB/s eta 0:00:30
#    ------- -------------------------------- 7.6/38.5 MB 1.0 MB/s eta 0:00:30
#    -------- ------------------------------- 7.9/38.5 MB 1.0 MB/s eta 0:00:30
#    -------- ------------------------------- 8.1/38.5 MB 1.0 MB/s eta 0:00:30
#    -------- ------------------------------- 8.4/38.5 MB 1.0 MB/s eta 0:00:30
#    -------- ------------------------------- 8.4/38.5 MB 1.0 MB/s eta 0:00:30
#    -------- ------------------------------- 8.7/38.5 MB 1.0 MB/s eta 0:00:30
#    --------- ------------------------------ 8.9/38.5 MB 1.0 MB/s eta 0:00:29
#    --------- ------------------------------ 9.2/38.5 MB 1.0 MB/s eta 0:00:29
#    --------- ------------------------------ 9.4/38.5 MB 1.0 MB/s eta 0:00:29
#    --------- ------------------------------ 9.4/38.5 MB 1.0 MB/s eta 0:00:29
#    ---------- ----------------------------- 9.7/38.5 MB 1.0 MB/s eta 0:00:29
#    ---------- ----------------------------- 10.0/38.5 MB 1.0 MB/s eta 0:00:28
#    ---------- ----------------------------- 10.2/38.5 MB 1.0 MB/s eta 0:00:28
#    ---------- ----------------------------- 10.2/38.5 MB 1.0 MB/s eta 0:00:28
#    ---------- ----------------------------- 10.5/38.5 MB 1.0 MB/s eta 0:00:28
#    ----------- ---------------------------- 10.7/38.5 MB 1.0 MB/s eta 0:00:28
#    ----------- ---------------------------- 11.0/38.5 MB 1.0 MB/s eta 0:00:27
#    ----------- ---------------------------- 11.3/38.5 MB 1.0 MB/s eta 0:00:27
#    ----------- ---------------------------- 11.5/38.5 MB 1.0 MB/s eta 0:00:27
#    ------------ --------------------------- 11.8/38.5 MB 1.0 MB/s eta 0:00:26
#    ------------ --------------------------- 12.1/38.5 MB 1.0 MB/s eta 0:00:26
#    ------------ --------------------------- 12.3/38.5 MB 1.0 MB/s eta 0:00:26
#    ------------- -------------------------- 12.6/38.5 MB 1.0 MB/s eta 0:00:25
#    ------------- -------------------------- 12.8/38.5 MB 1.0 MB/s eta 0:00:25
#    ------------- -------------------------- 12.8/38.5 MB 1.0 MB/s eta 0:00:25
#    ------------- -------------------------- 13.1/38.5 MB 1.0 MB/s eta 0:00:25
#    -------------- ------------------------- 13.6/38.5 MB 1.1 MB/s eta 0:00:24
#    -------------- ------------------------- 13.9/38.5 MB 1.1 MB/s eta 0:00:24
#    -------------- ------------------------- 14.2/38.5 MB 1.1 MB/s eta 0:00:23
#    -------------- ------------------------- 14.4/38.5 MB 1.1 MB/s eta 0:00:23
#    --------------- ------------------------ 14.7/38.5 MB 1.1 MB/s eta 0:00:23
#    --------------- ------------------------ 15.2/38.5 MB 1.1 MB/s eta 0:00:22
#    ---------------- ----------------------- 15.5/38.5 MB 1.1 MB/s eta 0:00:22
#    ---------------- ----------------------- 15.7/38.5 MB 1.1 MB/s eta 0:00:21
#    ---------------- ----------------------- 16.0/38.5 MB 1.1 MB/s eta 0:00:21
#    ---------------- ----------------------- 16.3/38.5 MB 1.1 MB/s eta 0:00:21
#    ----------------- ---------------------- 16.5/38.5 MB 1.1 MB/s eta 0:00:20
#    ----------------- ---------------------- 17.0/38.5 MB 1.1 MB/s eta 0:00:20
#    ----------------- ---------------------- 17.0/38.5 MB 1.1 MB/s eta 0:00:20
#    ----------------- ---------------------- 17.3/38.5 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.6/38.5 MB 1.1 MB/s eta 0:00:19
#    ------------------ --------------------- 17.6/38.5 MB 1.1 MB/s eta 0:00:19
#    ------------------ --------------------- 17.8/38.5 MB 1.1 MB/s eta 0:00:19
#    ------------------ --------------------- 18.1/38.5 MB 1.1 MB/s eta 0:00:19
#    ------------------- -------------------- 18.4/38.5 MB 1.1 MB/s eta 0:00:19
#    ------------------- -------------------- 18.4/38.5 MB 1.1 MB/s eta 0:00:19
#    ------------------- -------------------- 18.6/38.5 MB 1.1 MB/s eta 0:00:19
#    ------------------- -------------------- 18.9/38.5 MB 1.1 MB/s eta 0:00:18
#    ------------------- -------------------- 18.9/38.5 MB 1.1 MB/s eta 0:00:18
#    ------------------- -------------------- 19.1/38.5 MB 1.1 MB/s eta 0:00:18
#    -------------------- ------------------- 19.4/38.5 MB 1.1 MB/s eta 0:00:18
#    -------------------- ------------------- 19.7/38.5 MB 1.1 MB/s eta 0:00:18
#    -------------------- ------------------- 19.7/38.5 MB 1.1 MB/s eta 0:00:18
#    -------------------- ------------------- 19.9/38.5 MB 1.1 MB/s eta 0:00:18
#    -------------------- ------------------- 20.2/38.5 MB 1.1 MB/s eta 0:00:17
#    --------------------- ------------------ 20.4/38.5 MB 1.1 MB/s eta 0:00:17
#    --------------------- ------------------ 20.4/38.5 MB 1.1 MB/s eta 0:00:17
#    --------------------- ------------------ 20.7/38.5 MB 1.1 MB/s eta 0:00:17
#    --------------------- ------------------ 21.0/38.5 MB 1.1 MB/s eta 0:00:17
#    ---------------------- ----------------- 21.2/38.5 MB 1.1 MB/s eta 0:00:17
#    ---------------------- ----------------- 21.5/38.5 MB 1.1 MB/s eta 0:00:16
#    ---------------------- ----------------- 21.5/38.5 MB 1.1 MB/s eta 0:00:16
#    ---------------------- ----------------- 21.8/38.5 MB 1.1 MB/s eta 0:00:16
#    ---------------------- ----------------- 22.0/38.5 MB 1.1 MB/s eta 0:00:16
#    ----------------------- ---------------- 22.3/38.5 MB 1.1 MB/s eta 0:00:16
#    ----------------------- ---------------- 22.5/38.5 MB 1.1 MB/s eta 0:00:15
#    ----------------------- ---------------- 22.5/38.5 MB 1.1 MB/s eta 0:00:15
#    ----------------------- ---------------- 22.8/38.5 MB 1.1 MB/s eta 0:00:15
#    ----------------------- ---------------- 23.1/38.5 MB 1.1 MB/s eta 0:00:15
#    ------------------------ --------------- 23.3/38.5 MB 1.1 MB/s eta 0:00:15
#    ------------------------ --------------- 23.6/38.5 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 23.9/38.5 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 23.9/38.5 MB 1.1 MB/s eta 0:00:14
#    ------------------------- -------------- 24.1/38.5 MB 1.1 MB/s eta 0:00:14
#    ------------------------- -------------- 24.4/38.5 MB 1.1 MB/s eta 0:00:14
#    ------------------------- -------------- 24.6/38.5 MB 1.1 MB/s eta 0:00:13
#    ------------------------- -------------- 24.9/38.5 MB 1.1 MB/s eta 0:00:13
#    -------------------------- ------------- 25.4/38.5 MB 1.1 MB/s eta 0:00:13
#    -------------------------- ------------- 25.7/38.5 MB 1.1 MB/s eta 0:00:12
#    -------------------------- ------------- 26.0/38.5 MB 1.1 MB/s eta 0:00:12
#    -------------------------- ------------- 26.0/38.5 MB 1.1 MB/s eta 0:00:12
#    --------------------------- ------------ 26.2/38.5 MB 1.1 MB/s eta 0:00:12
#    --------------------------- ------------ 26.5/38.5 MB 1.1 MB/s eta 0:00:12
#    --------------------------- ------------ 26.7/38.5 MB 1.1 MB/s eta 0:00:11
#    ---------------------------- ----------- 27.0/38.5 MB 1.1 MB/s eta 0:00:11
#    ---------------------------- ----------- 27.3/38.5 MB 1.1 MB/s eta 0:00:11
#    ---------------------------- ----------- 27.5/38.5 MB 1.1 MB/s eta 0:00:11
#    ---------------------------- ----------- 27.8/38.5 MB 1.1 MB/s eta 0:00:10
#    ----------------------------- ---------- 28.3/38.5 MB 1.1 MB/s eta 0:00:10
#    ----------------------------- ---------- 28.6/38.5 MB 1.1 MB/s eta 0:00:10
#    ----------------------------- ---------- 28.8/38.5 MB 1.1 MB/s eta 0:00:09
#    ------------------------------ --------- 29.1/38.5 MB 1.1 MB/s eta 0:00:09
#    ------------------------------ --------- 29.4/38.5 MB 1.1 MB/s eta 0:00:09
#    ------------------------------ --------- 29.4/38.5 MB 1.1 MB/s eta 0:00:09
#    ------------------------------ --------- 29.6/38.5 MB 1.1 MB/s eta 0:00:09
#    ------------------------------- -------- 29.9/38.5 MB 1.1 MB/s eta 0:00:08
#    ------------------------------- -------- 30.1/38.5 MB 1.1 MB/s eta 0:00:08
#    ------------------------------- -------- 30.4/38.5 MB 1.1 MB/s eta 0:00:08
#    ------------------------------- -------- 30.7/38.5 MB 1.1 MB/s eta 0:00:08
#    -------------------------------- ------- 30.9/38.5 MB 1.1 MB/s eta 0:00:07
#    -------------------------------- ------- 31.2/38.5 MB 1.1 MB/s eta 0:00:07
#    -------------------------------- ------- 31.5/38.5 MB 1.1 MB/s eta 0:00:07
#    -------------------------------- ------- 31.7/38.5 MB 1.1 MB/s eta 0:00:07
#    --------------------------------- ------ 32.0/38.5 MB 1.1 MB/s eta 0:00:06
#    --------------------------------- ------ 32.0/38.5 MB 1.1 MB/s eta 0:00:06
#    --------------------------------- ------ 32.2/38.5 MB 1.1 MB/s eta 0:00:06
#    --------------------------------- ------ 32.5/38.5 MB 1.1 MB/s eta 0:00:06
#    ---------------------------------- ----- 32.8/38.5 MB 1.1 MB/s eta 0:00:06
#    ---------------------------------- ----- 33.0/38.5 MB 1.1 MB/s eta 0:00:05
#    ---------------------------------- ----- 33.3/38.5 MB 1.1 MB/s eta 0:00:05
#    ---------------------------------- ----- 33.6/38.5 MB 1.1 MB/s eta 0:00:05
#    ---------------------------------- ----- 33.6/38.5 MB 1.1 MB/s eta 0:00:05
#    ----------------------------------- ---- 33.8/38.5 MB 1.1 MB/s eta 0:00:05
#    ----------------------------------- ---- 34.1/38.5 MB 1.1 MB/s eta 0:00:05
#    ----------------------------------- ---- 34.1/38.5 MB 1.1 MB/s eta 0:00:05
#    ----------------------------------- ---- 34.3/38.5 MB 1.1 MB/s eta 0:00:04
#    ----------------------------------- ---- 34.3/38.5 MB 1.1 MB/s eta 0:00:04
#    ----------------------------------- ---- 34.6/38.5 MB 1.1 MB/s eta 0:00:04
#    ------------------------------------ --- 34.9/38.5 MB 1.1 MB/s eta 0:00:04
#    ------------------------------------ --- 35.1/38.5 MB 1.1 MB/s eta 0:00:04
#    ------------------------------------ --- 35.4/38.5 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 35.4/38.5 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 35.7/38.5 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 35.7/38.5 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 35.9/38.5 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 36.2/38.5 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 36.4/38.5 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 36.7/38.5 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 37.0/38.5 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 37.2/38.5 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 37.2/38.5 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 37.5/38.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  37.7/38.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 1.1 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
#
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed scikit-learn-1.7.1 scipy-1.16.1 threadpoolctl-3.6.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
# 2113    the #prophet as a #husband . #iphon : http://i...
# 2499    whi is my batteri go down whilst my phone is c...
# 2784    my #soni #xperiaz5 repair and up 2 date #netwo...
# 1847    happi . . . #maserati #maseratilevant #smile #...
# 3799    hey asshol i want my #googlemap and #youtub #a...
#                               ...
# 6777    rt @cutepenshopp the famili is a haven in a he...
# 4286    #new #phone :d !!!!!! so right now !!!!! #sams...
# 4063    my littl collection. i #case #iphon #color #co...
# 616     guess-works! #frankwilliams.ru #b7 #weekday #s...
# 1985    i see you :p #iphon #life #hiphop #obey #zumi ...
# Name: tweet, Length: 6336, dtype: object

# %%
X_test
# Out:
# 556     repost @alexx.lucero: #photooftheday #me #inst...
# 1139    happi new year 2018 cute 3d case iphon 7 7plu ...
# 506     iphon 5 is just like the 4s but thinner and ha...
# 7162    she' here! thank to @verizon , i won't throw m...
# 3526    @beatsbydr sound qualiti will like to go down ...
#                               ...
# 2729    i just updat everyth yesterday what do you mea...
# 127     endless love #instagram #instagood #instadaili...
# 1468    my late birthday gift #newcam #soni @ hotel hi...
# 7867    in other news, my ipod ha develop yet anoth fa...
# 7689    anoth iphon on hand after 3 years...;) #appl #...
# Name: tweet, Length: 1584, dtype: object

# %%
y_test
import numpy as np

# %%
def vectorizer(ds, vocabulary):
    vectorized_lst = []
    
    for sentence in ds:
        sentence_lst = np.zeros(len(vocabulary))
        
        for i in range(len(vocabulary)):
            if vocabulary[i] in sentence.split():
                sentence_lst[i] = 1
                
        vectorized_lst.append(sentence_lst)
        
    vectorized_lst_new = np.asarray(vectorized_lst, dtype=np.float32)
    
    return vectorized_lst_new

# %%
vectorized_x_train = vectorizer(X_train, tokens)

# %%
vectorized_x_test = vectorizer(X_test, tokens)

# %%
# !pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from imbalanced-learn) (2.3.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from imbalanced-learn) (1.16.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from imbalanced-learn) (1.7.1)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from imbalanced-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from imbalanced-learn) (3.6.0)
# Collecting scikit-learn<2,>=1.3.2 (from imbalanced-learn)
#   Downloading scikit_learn-1.6.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Downloading scikit_learn-1.6.1-cp313-cp313-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 398.4 kB/s eta 0:00:27
#    - -------------------------------------- 0.5/11.1 MB 398.4 kB/s eta 0:00:27
#    - -------------------------------------- 0.5/11.1 MB 398.4 kB/s eta 0:00:27
#    -- ------------------------------------- 0.8/11.1 MB 407.3 kB/s eta 0:00:26
#    -- ------------------------------------- 0.8/11.1 MB 407.3 kB/s eta 0:00:26
#    --- ------------------------------------ 1.0/11.1 MB 439.6 kB/s eta 0:00:23
#    --- ------------------------------------ 1.0/11.1 MB 439.6 kB/s eta 0:00:23
#    ---- ----------------------------------- 1.3/11.1 MB 482.4 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.3/11.1 MB 482.4 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.6/11.1 MB 514.9 kB/s eta 0:00:19
#    ----- ---------------------------------- 1.6/11.1 MB 514.9 kB/s eta 0:00:19
#    ------ --------------------------------- 1.8/11.1 MB 538.0 kB/s eta 0:00:18
#    ------- -------------------------------- 2.1/11.1 MB 558.0 kB/s eta 0:00:17
#    ------- -------------------------------- 2.1/11.1 MB 558.0 kB/s eta 0:00:17
#    -------- ------------------------------- 2.4/11.1 MB 572.9 kB/s eta 0:00:16
#    -------- ------------------------------- 2.4/11.1 MB 572.9 kB/s eta 0:00:16
#    --------- ------------------------------ 2.6/11.1 MB 587.7 kB/s eta 0:00:15
#    --------- ------------------------------ 2.6/11.1 MB 587.7 kB/s eta 0:00:15
#    ---------- ----------------------------- 2.9/11.1 MB 599.3 kB/s eta 0:00:14
#    ----------- ---------------------------- 3.1/11.1 MB 611.0 kB/s eta 0:00:13
#    ----------- ---------------------------- 3.1/11.1 MB 611.0 kB/s eta 0:00:13
#    ------------ --------------------------- 3.4/11.1 MB 623.4 kB/s eta 0:00:13
#    ------------ --------------------------- 3.4/11.1 MB 623.4 kB/s eta 0:00:13
#    ------------- -------------------------- 3.7/11.1 MB 629.8 kB/s eta 0:00:12
#    -------------- ------------------------- 3.9/11.1 MB 638.4 kB/s eta 0:00:12
#    -------------- ------------------------- 3.9/11.1 MB 638.4 kB/s eta 0:00:12
#    --------------- ------------------------ 4.2/11.1 MB 648.6 kB/s eta 0:00:11
#    ---------------- ----------------------- 4.5/11.1 MB 660.1 kB/s eta 0:00:11
#    ----------------- ---------------------- 4.7/11.1 MB 668.3 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.7/11.1 MB 668.3 kB/s eta 0:00:10
#    ----------------- ---------------------- 5.0/11.1 MB 667.6 kB/s eta 0:00:10
#    ----------------- ---------------------- 5.0/11.1 MB 667.6 kB/s eta 0:00:10
#    ----------------- ---------------------- 5.0/11.1 MB 667.6 kB/s eta 0:00:10
#    ------------------ --------------------- 5.2/11.1 MB 659.7 kB/s eta 0:00:09
#    ------------------ --------------------- 5.2/11.1 MB 659.7 kB/s eta 0:00:09
#    ------------------- -------------------- 5.5/11.1 MB 659.2 kB/s eta 0:00:09
#    -------------------- ------------------- 5.8/11.1 MB 662.7 kB/s eta 0:00:09
#    -------------------- ------------------- 5.8/11.1 MB 662.7 kB/s eta 0:00:09
#    --------------------- ------------------ 6.0/11.1 MB 668.2 kB/s eta 0:00:08
#    ---------------------- ----------------- 6.3/11.1 MB 676.2 kB/s eta 0:00:08
#    ---------------------- ----------------- 6.3/11.1 MB 676.2 kB/s eta 0:00:08
#    ----------------------- ---------------- 6.6/11.1 MB 680.3 kB/s eta 0:00:07
#    ------------------------ --------------- 6.8/11.1 MB 687.8 kB/s eta 0:00:07
#    ------------------------- -------------- 7.1/11.1 MB 693.7 kB/s eta 0:00:06
#    ------------------------- -------------- 7.1/11.1 MB 693.7 kB/s eta 0:00:06
#    -------------------------- ------------- 7.3/11.1 MB 699.7 kB/s eta 0:00:06
#    --------------------------- ------------ 7.6/11.1 MB 706.3 kB/s eta 0:00:05
#    --------------------------- ------------ 7.6/11.1 MB 706.3 kB/s eta 0:00:05
#    ---------------------------- ----------- 7.9/11.1 MB 711.8 kB/s eta 0:00:05
#    ----------------------------- ---------- 8.1/11.1 MB 716.8 kB/s eta 0:00:05
#    ------------------------------ --------- 8.4/11.1 MB 722.1 kB/s eta 0:00:04
#    ------------------------------ --------- 8.4/11.1 MB 722.1 kB/s eta 0:00:04
#    ------------------------------- -------- 8.7/11.1 MB 726.6 kB/s eta 0:00:04
#    -------------------------------- ------- 8.9/11.1 MB 731.1 kB/s eta 0:00:03
#    --------------------------------- ------ 9.2/11.1 MB 735.5 kB/s eta 0:00:03
#    --------------------------------- ------ 9.2/11.1 MB 735.5 kB/s eta 0:00:03
#    ---------------------------------- ----- 9.4/11.1 MB 740.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 9.7/11.1 MB 746.7 kB/s eta 0:00:02
#    ----------------------------------- ---- 9.7/11.1 MB 746.7 kB/s eta 0:00:02
#    ----------------------------------- ---- 9.7/11.1 MB 746.7 kB/s eta 0:00:02
#    ----------------------------------- ---- 9.7/11.1 MB 746.7 kB/s eta 0:00:02
#    ----------------------------------- ---- 9.7/11.1 MB 746.7 kB/s eta 0:00:02
#    ----------------------------------- ---- 10.0/11.1 MB 712.0 kB/s eta 0:00:02
#    ----------------------------------- ---- 10.0/11.1 MB 712.0 kB/s eta 0:00:02
#    ----------------------------------- ---- 10.0/11.1 MB 712.0 kB/s eta 0:00:02
#    ------------------------------------ --- 10.2/11.1 MB 696.2 kB/s eta 0:00:02
#    ------------------------------------- -- 10.5/11.1 MB 700.5 kB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.1 MB 707.1 kB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 714.7 kB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 715.5 kB/s eta 0:00:00
# Installing collected packages: scikit-learn, sklearn-compat, imbalanced-learn
#
#   Attempting uninstall: scikit-learn
#
#     Found existing installation: scikit-learn 1.7.1
#
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#     Uninstalling scikit-learn-1.7.1:
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.7.1
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ------------- -------------------------- 1/3 [sklearn-compat]
#    ------------- -------------------------- 1/3 [sklearn-compat]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    ---------------------------------------- 3/3 [imbalanced-learn]
#
# Successfully installed imbalanced-learn-0.13.0 scikit-learn-1.6.1 sklearn-compat-0.1.3
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\Desktop\sentiment_analysis_project\env\Lib\site-packages\~klearn'.
#   You can safely remove it manually.

# %%
y.value_counts()
# Out:
# label
# 0    5894
# 1    2026
# Name: count, dtype: int64

# %%
pip install --upgrade --force-reinstall scikit-learn imbalanced-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting imbalanced-learn
#   Using cached imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting numpy>=1.22.0 (from scikit-learn)
#   Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Using cached scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn)
#   Using cached sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Using cached imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl (12.8 MB)
# Using cached scipy-1.16.1-cp313-cp313-win_amd64.whl (38.5 MB)
# Using cached sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Using cached scikit_learn-1.6.1-cp313-cp313-win_amd64.whl (11.1 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn, sklearn-compat, imbalanced-learn
#
#   Attempting uninstall: threadpoolctl
#
#     Found existing installation: threadpoolctl 3.6.0
#
#     Uninstalling threadpoolctl-3.6.0:
#
#    ---------------------------------------- 0/7 [threadpoolctl]
#    ---------------------------------------- 0/7 [threadpoolctl]
#    ---------------------------------------- 0/7 [threadpoolctl]
#    ---------------------------------------- 0/7 [threadpoolctl]
#    ---------------------------------------- 0/7 [threadpoolctl]
#    ---------------------------------------- 0/7 [threadpoolctl]
#    ---------------------------------------- 0/7 [threadpoolctl]
#    ---------------------------------------- 0/7 [threadpoolctl]
#    ---------------------------------------- 0/7 [threadpoolctl]
#       Successfully uninstalled threadpoolctl-3.6.0
#    ---------------------------------------- 0/7 [threadpoolctl]
#   Attempting uninstall: numpy
#    ---------------------------------------- 0/7 [threadpoolctl]
#     Found existing installation: numpy 2.3.2
#    ---------------------------------------- 0/7 [threadpoolctl]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#     Uninstalling numpy-2.3.2:
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#       Successfully uninstalled numpy-2.3.2
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#   Attempting uninstall: joblib
#    ----- ---------------------------------- 1/7 [numpy]
#     Found existing installation: joblib 1.5.1
#    ----- ---------------------------------- 1/7 [numpy]
#     Uninstalling joblib-1.5.1:
#    ----- ---------------------------------- 1/7 [numpy]
#       Successfully uninstalled joblib-1.5.1
#    ----- ---------------------------------- 1/7 [numpy]
#    ----------- ---------------------------- 2/7 [joblib]
#    ----------- ---------------------------- 2/7 [joblib]
#    ----------- ---------------------------- 2/7 [joblib]
#    ----------- ---------------------------- 2/7 [joblib]
#    ----------- ---------------------------- 2/7 [joblib]
#    ----------- ---------------------------- 2/7 [joblib]
#    ----------- ---------------------------- 2/7 [joblib]
#    ----------- ---------------------------- 2/7 [joblib]
#   Attempting uninstall: scipy
#    ----------- ---------------------------- 2/7 [joblib]
#     Found existing installation: scipy 1.16.1
#    ----------- ---------------------------- 2/7 [joblib]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#     Uninstalling scipy-1.16.1:
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#       Successfully uninstalled scipy-1.16.1
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#    ----------------- ---------------------- 3/7 [scipy]
#   Attempting uninstall: scikit-learn
#    ----------------- ---------------------- 3/7 [scipy]
#     Found existing installation: scikit-learn 1.6.1
#    ----------------- ---------------------- 3/7 [scipy]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#     Uninstalling scikit-learn-1.6.1:
#    ---------------------- ----------------- 4/7 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.6.1
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------- ----------------- 4/7 [scikit-learn]
#   Attempting uninstall: sklearn-compat
#    ---------------------- ----------------- 4/7 [scikit-learn]
#     Found existing installation: sklearn-compat 0.1.3
#    ---------------------- ----------------- 4/7 [scikit-learn]
#     Uninstalling sklearn-compat-0.1.3:
#    ---------------------- ----------------- 4/7 [scikit-learn]
#       Successfully uninstalled sklearn-compat-0.1.3
#    ---------------------- ----------------- 4/7 [scikit-learn]
#   Attempting uninstall: imbalanced-learn
#    ---------------------- ----------------- 4/7 [scikit-learn]
#     Found existing installation: imbalanced-learn 0.13.0
#    ---------------------- ----------------- 4/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [imbalanced-learn]
#     Uninstalling imbalanced-learn-0.13.0:
#    ---------------------------------- ----- 6/7 [imbalanced-learn]
#       Successfully uninstalled imbalanced-learn-0.13.0
#    ---------------------------------- ----- 6/7 [imbalanced-learn]
#    ---------------------------------- ----- 6/7 [imbalanced-learn]
#    ---------------------------------- ----- 6/7 [imbalanced-learn]
#    ---------------------------------- ----- 6/7 [imbalanced-learn]
#    ---------------------------------- ----- 6/7 [imbalanced-learn]
#    ---------------------------------- ----- 6/7 [imbalanced-learn]
#    ---------------------------------- ----- 6/7 [imbalanced-learn]
#    ---------------------------------------- 7/7 [imbalanced-learn]
#
# Successfully installed imbalanced-learn-0.13.0 joblib-1.5.1 numpy-2.3.2 scikit-learn-1.6.1 scipy-1.16.1 sklearn-compat-0.1.3 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\Desktop\sentiment_analysis_project\env\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\Desktop\sentiment_analysis_project\env\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\Desktop\sentiment_analysis_project\env\Lib\site-packages\~cipy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\Desktop\sentiment_analysis_project\env\Lib\site-packages\~cipy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\Desktop\sentiment_analysis_project\env\Lib\site-packages\~-learn'.
#   You can safely remove it manually.

# %%
pip install --upgrade imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (0.12.0)
# Collecting imbalanced-learn
#   Using cached imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from imbalanced-learn) (2.3.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from imbalanced-learn) (1.16.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from imbalanced-learn) (1.7.1)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn)
#   Using cached sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from imbalanced-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\user\desktop\sentiment_analysis_project\env\lib\site-packages (from imbalanced-learn) (3.6.0)
# Collecting scikit-learn<2,>=1.3.2 (from imbalanced-learn)
#   Using cached scikit_learn-1.6.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Using cached imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Using cached sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Using cached scikit_learn-1.6.1-cp313-cp313-win_amd64.whl (11.1 MB)
# Installing collected packages: scikit-learn, sklearn-compat, imbalanced-learn
#
#   Attempting uninstall: scikit-learn
#
#     Found existing installation: scikit-learn 1.7.1
#
#    ---------------------------------------- 0/3 [scikit-learn]
#     Uninstalling scikit-learn-1.7.1:
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.7.1
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#   Attempting uninstall: imbalanced-learn
#    ---------------------------------------- 0/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#     Found existing installation: imbalanced-learn 0.12.0
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#     Uninstalling imbalanced-learn-0.12.0:
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#       Successfully uninstalled imbalanced-learn-0.12.0
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    -------------------------- ------------- 2/3 [imbalanced-learn]
#    ---------------------------------------- 3/3 [imbalanced-learn]
#
# Successfully installed imbalanced-learn-0.13.0 scikit-learn-1.6.1 sklearn-compat-0.1.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\Desktop\sentiment_analysis_project\env\Lib\site-packages\~.learn'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.1
